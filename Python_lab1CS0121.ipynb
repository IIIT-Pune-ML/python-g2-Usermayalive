# %% [markdown]
# # Python Programming basics

# %% [markdown]
# ## Types and Functions

# %% [markdown]
# Extend the function to take an optional 3rd argument.

# %% [markdown]
# Extend the function to take another optional flag parameter and add only if it is true

# %%
def add(x, y, z=None, flag=None):
    if flag is not None and not flag:
        return None
    if z is not None:
        return x + y + z
    return x + y

# Testing different cases of the add function
print("add(1, 2) =", add(1, 2))
print("add(1, 2, 3) =", add(1, 2, 3))
print("add(1, 2, flag=True) =", add(1, 2, flag=True))
print("add(1, 2, flag=False) =", add(1, 2, flag=False))

# %% [markdown]
# Assign a function to a variable 'a' and print the output

# %%
a = add
print("Calling through variable a:", a(5, 6))

# %% [markdown]
# ## Iterations in python

# %% [markdown]
# Create a list of 5 elements

# %%
my_list = [2, 4, 6, 8, 10]
print("Created list:", my_list)

# %%
my_list = [2, 4, 6, 8, 10]
print("Created list:", my_list)

# %% [markdown]
# Square every item in the list using a loop inside the array index

# %%
for i in range(len(my_list)):
    my_list[i] = my_list[i] ** 2
print("Squared list:", my_list)

# %%
for i in range(len(my_list)):
    my_list[i] = my_list[i] ** 2
print("Squared list:", my_list)

# %% [markdown]
# Show how to use a iterator. First, use enumerate to create a new tuple from above list

# %%
# use of an iterator starting with 25 and squaring every next call
class MyInit:
    def __init__(self):
        self.a = 25
    def __iter__(self):
        return self
    def __next__(self):
        x = self.a
        self.a = self.a ** 2
        return x

obj1 = MyInit()
itr = iter(obj1)

print("First next(itr):", next(itr))
print("Second next(itr):", next(itr))
print("Third next(itr):", next(itr))

# %%
# First, use enumerate to create a new tuple from the list
listSequence = ["eat", "sleep", "repeat"]

tup_list = []
for index, item in enumerate(listSequence):
    tup_list.append((index, item))
tup = tuple(tup_list)

print("Tuple using enumerate:", tup)

# %% [markdown]
# Now use a zip iterator to do the same.

# %%
# Using zip iterator to pair indices and elements
indices = list(range(len(listSequence)))
tup_zip = tuple(zip(indices, listSequence))
print("Tuple using zip:", tup_zip)

# %%
# Using zip iterator to pair indices and elements
indices = list(range(len(listSequence)))
tup_zip = tuple(zip(indices, listSequence))
print("Tuple using zip:", tup_zip)

# %% [markdown]
# Now state the differences between a zip and enumerate iterator.

# %% [markdown]
# Python`enumerate()` and `zip()` are built-in functions that can be used on sequences.
#
# `enumerate()` function can be use to iterate over indices and items of a list.
#
# `zip()` function make an iterator that aggregates elements from each of the iterables. In simple words it can be used to iterate over two or more lists in parallel.

# %% [markdown]
# ## Strings in Python

# %% [markdown]
# Open the file poem.txt and print lenght of each line.

# %%
# Open the file poem.txt and print the length of each line
with open('poem.txt', 'r') as file:
    line_lengths = [len(line) for line in file]
print("Lengths of first 30 lines:", line_lengths[:30])
print("Total lines in file:", len(line_lengths))

# %% [markdown]
# Find sum of each line, mean, median and standard deviation of all lines in the file.

# %%
import statistics
with open('poem.txt', 'r') as file:
    line_lengths = [len(line) for line in file]
total_len_chars = sum(line_lengths)
mean_len = statistics.mean(line_lengths)
median_len = statistics.median(line_lengths)
stdev_len = statistics.stdev(line_lengths)
print("Sum of all line lengths (total characters):", total_len_chars)
print(f"Mean line length: {mean_len:.2f}")
print(f"Median line length: {median_len:.2f}")
print(f"Standard deviation of line lengths: {stdev_len:.2f}")

# %%
import statistics
total_len_chars = sum(line_lengths)
mean_len = statistics.mean(line_lengths)
median_len = statistics.median(line_lengths)
stdev_len = statistics.stdev(line_lengths)
print("Sum of all line lengths (total characters):", total_len_chars)
print(f"Mean line length: {mean_len:.2f}")
print(f"Median line length: {median_len:.2f}")
print(f"Standard deviation of line lengths: {stdev_len:.2f}")

# %% [markdown]
# Count the number of words in the file

# %%
with open('poem.txt', 'r') as file:
    words = file.read().split()
print("Total word count:", len(words))

# %%
with open('poem.txt', 'r') as file:
    words = file.read().split()
print("Total word count:", len(words))

# %% [markdown]
# Print the first 1000 characters from poem.txt.

# %%
with open('poem.txt', 'r') as file:
    content = file.read()
print(content[:1000])

# %%
with open('poem.txt', 'r') as file:
    content = file.read()
print(content[:1000])

# %% [markdown]
# Print the 3rd to 5th words from the file.

# %%
with open('poem.txt', 'r') as file:
    words = file.read().split()
# 3rd to 5th words (indices 2, 3, 4)
print("3rd to 5th words:", words[2:5])

# %%
# 3rd to 5th words (indices 2, 3, 4)
print("3rd to 5th words:", words[2:5])

# %%
with open('poem.txt', 'r') as file:
    # Read and print the first 10 lines of the poem
    for i, line in enumerate(file):
        if i < 10:
            print(f"Line {i+1}: {line.strip()}")
        else:
            break

# %% [markdown]
# Get every third word between the second and the 15th words from poem.txt.

# %%
with open('poem.txt', 'r') as file:
    words = file.read().split()
# Second word (index 1) to 15th word (index 14)
print("Every third word between 2nd and 15th:", words[1:15:3])

# %%
# Second word (index 1) to 15th word (index 14)
print("Every third word between 2nd and 15th:", words[1:15:3])

# %% [markdown]
# Print the last word from the file and change the second last characted in the string to 'g'.

# %%
with open('poem.txt', 'r') as file:
    words = file.read().split()
last_word = words[-1]
print("Last word:", last_word)
try:
    last_word[-2] = 'g'
except TypeError as e:
    print("Error attempting in-place assignment of string:", e)

# %%
last_word = words[-1]
print("Last word:", last_word)
try:
    last_word[-2] = 'g'
except TypeError as e:
    print("Error attempting in-place assignment of string:", e)

# %% [markdown]
# State if the above operation completed successfully. State reasons
#
# **Answer:** The operation did not complete successfully. It raised a `TypeError`. This occurs because strings in Python are immutable data types, meaning they cannot be modified in place once created. Attempting to assign a new character to a specific index (like `last_word[-2] = 'g'`) is not supported.

# %% [markdown]
# # Find types of Python variables and functions

# %% [markdown]
# Find what are the types of the following and state if they are mutable of immutable

# %%
# Print the types and mutability of these entities
items = [
    (None, "Immutable"),
    (1, "Immutable"),
    (1.0, "Immutable"),
    (add, "Immutable (function object)"),
    ((1, 'a', 3, 'b'), "Immutable (tuple)"),
    ([1, 'a', 3, 'b'], "Mutable (list)")
]
for val, mut in items:
    print(f"Value: {repr(val):<25} | Type: {str(type(val)):<25} | {mut}")

# %% [markdown]
# Append new elements at the end of a list

# %%
test_list = [10, 20, 30]
test_list.append(40)
test_list.append(50)
print("List after append:", test_list)

# %%
test_list = [10, 20, 30]
test_list.append(40)
test_list.append(50)
print("List after append:", test_list)

# %% [markdown]
# Loop through each element of the list

# %%
for val in test_list:
    print("Element:", val)

# %%
for val in test_list:
    print("Element:", val)

# %% [markdown]
# Use a indexing operator

# %%
# Using indexing operator
str_indexing = "IIITG"
lastchar = str_indexing[-1]
print("Last character:", lastchar)

# %% [markdown]
# Concatenate two lists

# %%
list_x = [1, 2, 3]
list_y = [4, 5, 6]
concatenated = list_x + list_y
print("Concatenated:", concatenated)

# %%
list_x = [1, 2, 3]
list_y = [4, 5, 6]
concatenated = list_x + list_y
print("Concatenated:", concatenated)

# %% [markdown]
# Use * to repeat lists

# %%
repeated = [1, 2] * 4
print("Repeated:", repeated)

# %%
repeated = [1, 2] * 4
print("Repeated:", repeated)

# %% [markdown]
# Use the in operator to check if something is in a list

# %%
fruits = ['apple', 'banana', 'orange']
print("Is 'banana' in list?", 'banana' in fruits)
print("Is 'grape' in list?", 'grape' in fruits)

# %%
fruits = ['apple', 'banana', 'orange']
print("Is 'banana' in list?", 'banana' in fruits)
print("Is 'grape' in list?", 'grape' in fruits)

# %% [markdown]
# Initialize a string and slice the first 1, 2 and 3 characters. Then from 3rd to end.

# %%
s_val = "PythonClass"
print("First 1:", s_val[:1])
print("First 2:", s_val[:2])
print("First 3:", s_val[:3])
print("From 3rd to end:", s_val[2:])

# %%
s_val = "PythonClass"
print("First 1:", s_val[:1])
print("First 2:", s_val[:2])
print("First 3:", s_val[:3])
print("From 3rd to end:", s_val[2:])

# %% [markdown]
# Take a first name and a last name and then concatenate the last name with 3 times the first name and show result.

# %%
first_n = "Dip"
last_n = "Sankar"
res = last_n + (first_n * 3)
print("Concatenated name result:", res)

# %%
first_n = "Dip"
last_n = "Sankar"
res = last_n + (first_n * 3)
print("Concatenated name result:", res)

# %% [markdown]
# Take a string with four words. Use the split function to display the second and the last words

# %%
four_word_str = "Machine Learning is great"
words_split = four_word_str.split()
print("Second word:", words_split[1])
print("Last word:", words_split[-1])

# %%
four_word_str = "Machine Learning is great"
words_split = four_word_str.split()
print("Second word:", words_split[1])
print("Last word:", words_split[-1])

# %% [markdown]
# Concatenate a number with a string. Update following:

# %%
code_num = 101
dept_str = "CS"
final_code = dept_str + str(code_num)
print("Concatenated result:", final_code)

# %%
code_num = 101
dept_str = "CS"
final_code = dept_str + str(code_num)
print("Concatenated result:", final_code)

# %% [markdown]
# ## Dictionaries associated with lists

# %% [markdown]
# Create a list of keys and values

# %%
# Create dictionary x
x = {}

# %%
# Create dictionary x
x = {}

# %%
x['Prithwish'] = 'prithwish.sen@iiitg'
x['Dip'] = 'dip@iiitg'
x['Sankar'] = 'sankar@iiitg'
print("Dictionary x:", x)

# %% [markdown]
# Iterate over all the keys

# %%
for key in x.keys():
    print("Key:", key)

# %%
for key in x.keys():
    print("Key:", key)

# %% [markdown]
# Iterate over all the values

# %%
for val in x.values():
    print("Value:", val)

# %%
for val in x.values():
    print("Value:", val)

# %% [markdown]
# Iterate over all the key-value pairs in the list

# %%
for k, v in x.items():
    print(f"Key: {k} | Value: {v}")

# %%
for k, v in x.items():
    print(f"Key: {k} | Value: {v}")

# %% [markdown]
# Unpack the following sequence into different variables

# %%
name, inst, email, dept = ('Prithwish', 'IIITG', 'prithwish.sen@iiitg', 'CSE')
print("Name:", name)
print("Institution:", inst)
print("Email:", email)
print("Department:", dept)

# %% [markdown]
# Use Python's in-built methods for string formatting

# %%
sales_record = {
    'price': 3.24,
    'num_items': 4,
    'person': 'Prithwish'
}

sales_statement = '{} got {} item(s) at a cost of {} each for a total of {}'

total_cost = sales_record['price'] * sales_record['num_items']
print(sales_statement.format(
    sales_record['person'],
    sales_record['num_items'],
    sales_record['price'],
    total_cost
))

# %% [markdown]
# Take a list of 10 elements and convert into json using  json library. Demonstrate use of loads and dumps

# %%
import json
my_10_list = [1, "apple", 3.14, True, None, [5, 6], {"a": 1}, False, "banana", 10]
json_data = json.dumps(my_10_list)
print("JSON string (dumps):", json_data)
parsed_back = json.loads(json_data)
print("Parsed list (loads):", parsed_back)

# %%
import json
my_10_list = [1, "apple", 3.14, True, None, [5, 6], {"a": 1}, False, "banana", 10]
json_data = json.dumps(my_10_list)
print("JSON string (dumps):", json_data)
parsed_back = json.loads(json_data)
print("Parsed list (loads):", parsed_back)

# %% [markdown]
# # Python objects and functions

# %% [markdown]
# Take the following code:

# %%
class students:
    dept = "Department of CSE"
    def assign_name(self, n):
        self.name = n
    def assign_location(self, l):
        self.location = l

# %% [markdown]
# Create a object of the class above. Set name and location of your choice.

# %%
student_obj = students()
student_obj.assign_name("Dip Sankar")
student_obj.assign_location("Guwahati, Assam, India")

# %%
student_obj = students()
student_obj.assign_name("Dip Sankar")
student_obj.assign_location("Guwahati, Assam, India")

# %% [markdown]
# Format accordingly and print in a manner so we see something like : "Dip Sankar lives in Guwahati, Assam, India and works in the Department of CSE". The name and location should be of your choice. Use 1 print only

# %%
sentence = '{} lives in {} and is a student in the {}'
print(sentence.format(student_obj.name, student_obj.location, student_obj.dept))

# %% [markdown]
# Create two lists of 5 elements each. Map the min function to the lists using map(). Print the minimum object.

# %%
list_a = [12, 4, 18, 9, 23]
list_b = [7, 15, 10, 14, 5]
min_object = map(min, list_a, list_b)
print("Minimum map object:", min_object)

# %%
list_a = [12, 4, 18, 9, 23]
list_b = [7, 15, 10, 14, 5]
min_object = map(min, list_a, list_b)
print("Minimum map object:", min_object)

# %% [markdown]
# Iterate through that object and print the elements.

# %%
print("Iterating map object elements:")
for element in min_object:
    print(element)

# %%
print("Iterating map object elements:")
for element in min_object:
    print(element)

# %% [markdown]
# # Working with CSV

# %% [markdown]
# Let's import a file with fuel economy data

# %%
import csv
with open('mpg.csv') as csvfile:
    mpg = list(csv.DictReader(csvfile))

# %% [markdown]
# Find out how many items are there in the dictionary

# %%
print("Number of records (dictionaries) in mpg list:", len(mpg))
print("Key-value pairs of the second record:")
for item in mpg[1].items():
    print(item)

# %% [markdown]
# Find the column names with keys

# %%
print("Column names (keys):", list(mpg[0].keys()))

# %%
print("Column names (keys):", list(mpg[0].keys()))

# %% [markdown]
# Find the average cty fuel economy across all cars. All values in the dictionaries are strings.

# %%
avg_cty = sum(float(d['cty']) for d in mpg) / len(mpg)
print(f"Average city fuel economy: {avg_cty:.4f} mpg")

# %%
avg_cty = sum(float(d['cty']) for d in mpg) / len(mpg)
print(f"Average city fuel economy: {avg_cty:.4f} mpg")

# %% [markdown]
# Find the average hwy fuel economy across all cars

# %%
avg_hwy = sum(float(d['hwy']) for d in mpg) / len(mpg)
print(f"Average highway fuel economy: {avg_hwy:.4f} mpg")

# %%
avg_hwy = sum(float(d['hwy']) for d in mpg) / len(mpg)
print(f"Average highway fuel economy: {avg_hwy:.4f} mpg")

# %% [markdown]
# Use set to return the unique values for the number of cylinders the cars.

# %%
cylinders = set(d['cyl'] for d in mpg)
print("Unique cylinder counts:", sorted(list(cylinders)))

# %% [markdown]
# Group the cars by number of cylinder, and finding the average cty mpg for each group.

# %%
MpgByCyl = []

for c in cylinders: # iterate over all the cylinder levels
    summpg = 0
    typecount = 0
    for d in mpg: # iterate over all dictionaries
        if d['cyl'] == c:      
            summpg += float(d['cty'])
            typecount += 1
    MpgByCyl.append((c, summpg / typecount))

MpgByCyl.sort(key=lambda x: x[0])
print(MpgByCyl)
# Out:
# [('4', 21.012345679012345),
#  ('5', 20.5),
#  ('6', 16.21518987341772),
#  ('8', 12.571428571428571)]

# %% [markdown]
# Return the unique values for the class types in our dataset using set.

# %%
vehicleclass = set(d['class'] for d in mpg)
print("Unique vehicle classes:", vehicleclass)

# %% [markdown]
# Find average miles per gallon in the highway for each class of vehicles

# %%
MileageByClass = []

for t in vehicleclass: # iterate over all the vehicle classes
    sumpg = 0
    classCount = 0
    for d in mpg: 
        if d['class'] == t:                 
            sumpg += float(d['hwy'])
            classCount += 1
    MileageByClass.append((t, sumpg / classCount)) 

MileageByClass.sort(key=lambda x: x[1])
print(MileageByClass)
